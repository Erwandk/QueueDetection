# %% [markdown]
# # Modèle regression
# Ce script a pour but de développer le modèle de deep learning en régression. L'objectif est de labelliser les photos de la queue du RU en renseignant le nombre de personnes dessus.
#
# ##### Importation des librairies

# %%
import os
import cv2
import time
import numpy as np
from random import randint
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ##### Lecture des données

# %%
# Chemin vers les données
PATH_IMG = "/home/erwan/Centrale/OSY/DEEPL/Projet/QueueDetection/data/img/"
PATH_LABEL = "/home/erwan/Centrale/OSY/DEEPL/Projet/QueueDetection/data/labels/regression"

# %%
# VARIABLES GLOBALES
IMAGE_SIZE = 256
BATCH_SIZE = 16
NB_EPOCH = 25

# dataset que l'on souhaite charger en plus des photos initiales
# issues du script d'augmentation de données
data_augmented = {
    'blur': False,
    'contrast': False,
    'brightness': False,
    'noise': True
}

# %%
def read_data_folder(path_img, path_labels, img_size=256):
    """
    Lit les images et labels contenus dans un répertoire.
    """
    x_data = list()
    y_data = list()
    
    for file in os.listdir(path_img):
        if not os.path.isfile(os.path.join(path_img, file)):
            continue
        img_name, ext = file.split(".")
        lab_name = str(img_name) + ".txt"
        if lab_name in os.listdir(path_labels):
            # Lecture de l'image
            img_path = os.path.join(path_img, file)
            img = cv2.imread(img_path, cv2.IMREAD_COLOR)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (img_size, img_size)).astype(np.float32)
            # Lecture du label
            with open(os.path.join(path_labels, lab_name), 'r') as file_label:
                label = file_label.read()
            # Ajout de la donnée
            x_data.append(img)
            y_data.append(int(label))
    return x_data, y_data

# %%
def load_data(path_img, path_labels, data_augm, img_size=256, normalize=False):
    """
    Lit les images et leur labels, charge optionnellement leurs transformations réalisées lors de 
    l'étape de data augmentation, resize les photos et optionnellement les normalise.
    """
    x_data = list()
    y_data = list()
    print("Lecture des données...")
    # Lecture des données principales
    x, y = read_data_folder(path_img, path_labels)
    x_data.extend(x)
    y_data.extend(y)
    
    # Lecture des dossiers de data_augmentation
    new_path_labels = os.path.join(path_labels, 'data_augmentation')
    if 'blur' in data_augm and data_augm['blur']:
        x, y = read_data_folder(os.path.join(path_img, 'data_augmentation', 'blur'), new_path_labels)
        x_data.extend(x)
        y_data.extend(y)
    if 'contrast' in data_augm and data_augm['contrast']:
        x, y = read_data_folder(os.path.join(path_img, 'data_augmentation', 'contrast'), new_path_labels)
        x_data.extend(x)
        y_data.extend(y)
    if 'brightness' in data_augm and data_augm['brightness']:
        x, y = read_data_folder(os.path.join(path_img, 'data_augmentation', 'brightness'), new_path_labels)
        x_data.extend(x)
        y_data.extend(y)
    if 'noise' in data_augm and data_augm['noise']:
        x, y = read_data_folder(os.path.join(path_img, 'data_augmentation', 'noise'), new_path_labels)
        x_data.extend(x)
        y_data.extend(y)
    
    x_data = np.array(x_data, dtype=np.float32)
    y_data = np.array(y_data, dtype=np.float32)
    
    if normalize:
        m = x_data.mean()
        s = x_data.std()
        x_data -= m
        x_data /= s
    
    print("Nombre de données : {}".format(len(x_data)))
    return x_data, y_data

# %%
t1 = time.time()
x_data, y_data = load_data(PATH_IMG, PATH_LABEL, data_augmented, normalize=False, img_size=IMAGE_SIZE)
t2 = time.time()
print("Durée pour lire les données : {}s".format(round(t2-t1, 3)))
# Out:
# Lecture des données...
# Nombre de données : 674
# Durée pour lire les données : 78.892s

# %% [markdown]
# ##### Séparation en train et test set

# %%
def split_dataset(x_data, y_data):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, 
                                                        shuffle=True, test_size=0.2, random_state=123)
    print("Taille set train : {}".format(len(x_train)))
    print("Taille set test : {}".format(len(x_test)))
    return x_train, x_test, y_train, y_test

# %%
x_train, x_test, y_train, y_test = split_dataset(x_data, y_data)
# Out:
# Taille set train : 539
# Taille set test : 135

# %%
def display_random(data_set):
    i = randint(0, len(data_set)-1)
    img = data_set[i]
    plt.figure(figsize=(10, 10))
    plt.imshow(img.astype(np.uint8), interpolation='nearest')
    plt.axis('off')
    plt.show()
    return img

# %%
_ = display_random(x_train)

# %% [markdown]
# ##### Création du modèle de deep learning
# Nous avons optimisé les hyper-paramètres du réseau en entrainant plusieurs modèles.
# Le modèle ci-dessous resulte de l'optimisation de ceux-ci.

# %%
def create_model(input_shape, nb_filters=16, nb_conv=5):

    model = Sequential()
    model.add(Conv2D(nb_filters, kernel_size=(nb_conv, nb_conv), strides=(1, 1),
                     activation='relu', padding='valid',
                     input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    model.add(Conv2D(nb_filters*2, kernel_size=(nb_conv, nb_conv), activation='relu', padding='valid'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(nb_filters*2, activation='relu'))
    model.add(Dense(1, activation='linear'))

    adam = Adam(lr=0.0001)
    model.compile(loss='mean_squared_error', optimizer=adam, metrics=['mae'])
    model.summary()
    
    return model

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
model = create_model(input_shape, nb_filters=32, nb_conv=5)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 252, 252, 32)      2432
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 126, 126, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 122, 122, 64)      51264
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 61, 61, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 238144)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 238144)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                15241280
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 15,295,041
# Trainable params: 15,295,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Entrainement du modèle crée

# %%
def train_model(model, x_train, y_train, batch_size=50, nb_epoch=1000):

    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epoch, verbose=2, 
                        validation_split=0.2)

    return history, model

# %%
history, model = train_model(model, x_train, y_train, batch_size=BATCH_SIZE, nb_epoch=NB_EPOCH)
# Out:
# Train on 431 samples, validate on 108 samples
# Epoch 1/25
# 101s - loss: 113067.9898 - mean_absolute_error: 150.0721 - val_loss: 422.0458 - val_mean_absolute_error: 17.5987
# Epoch 2/25
# 87s - loss: 349.9432 - mean_absolute_error: 14.9164 - val_loss: 119.7639 - val_mean_absolute_error: 9.4568
# Epoch 3/25
# 88s - loss: 169.6284 - mean_absolute_error: 10.5542 - val_loss: 51.7262 - val_mean_absolute_error: 5.3405
# Epoch 4/25
# 92s - loss: 123.9381 - mean_absolute_error: 8.6539 - val_loss: 83.0758 - val_mean_absolute_error: 7.5751
# Epoch 5/25
# 86s - loss: 78.8029 - mean_absolute_error: 6.9728 - val_loss: 27.5796 - val_mean_absolute_error: 4.2581
# Epoch 6/25
# 86s - loss: 58.3909 - mean_absolute_error: 6.1779 - val_loss: 58.9661 - val_mean_absolute_error: 6.6503
# Epoch 7/25
# 92s - loss: 67.1684 - mean_absolute_error: 6.3992 - val_loss: 26.1187 - val_mean_absolute_error: 4.2113
# Epoch 8/25
# 89s - loss: 60.8662 - mean_absolute_error: 6.2970 - val_loss: 20.6000 - val_mean_absolute_error: 3.7683
# Epoch 9/25
# 88s - loss: 58.9992 - mean_absolute_error: 6.1697 - val_loss: 41.1036 - val_mean_absolute_error: 5.5003
# Epoch 10/25
# 86s - loss: 53.8409 - mean_absolute_error: 5.9417 - val_loss: 74.9446 - val_mean_absolute_error: 7.7183
# Epoch 11/25
# 86s - loss: 50.6378 - mean_absolute_error: 5.7407 - val_loss: 19.0600 - val_mean_absolute_error: 3.5767
# Epoch 12/25
# 86s - loss: 41.4789 - mean_absolute_error: 5.2377 - val_loss: 40.6252 - val_mean_absolute_error: 5.4543
# Epoch 13/25
# 86s - loss: 41.6103 - mean_absolute_error: 5.0856 - val_loss: 18.3818 - val_mean_absolute_error: 3.3759
# Epoch 14/25
# 86s - loss: 32.9306 - mean_absolute_error: 4.6485 - val_loss: 16.8453 - val_mean_absolute_error: 3.3326
# Epoch 15/25
# 86s - loss: 30.9501 - mean_absolute_error: 4.4483 - val_loss: 16.2636 - val_mean_absolute_error: 3.3279
# Epoch 16/25
# 86s - loss: 32.3019 - mean_absolute_error: 4.4518 - val_loss: 16.0080 - val_mean_absolute_error: 3.3077
# Epoch 17/25
# 86s - loss: 30.1111 - mean_absolute_error: 4.4260 - val_loss: 17.7867 - val_mean_absolute_error: 3.3969
# Epoch 18/25
# 86s - loss: 29.5986 - mean_absolute_error: 4.4286 - val_loss: 26.7862 - val_mean_absolute_error: 4.3817
# Epoch 19/25
# 86s - loss: 30.6571 - mean_absolute_error: 4.4170 - val_loss: 25.6251 - val_mean_absolute_error: 4.2964
# Epoch 20/25
# 86s - loss: 27.1762 - mean_absolute_error: 4.2268 - val_loss: 15.2249 - val_mean_absolute_error: 3.1658
# Epoch 21/25
# 86s - loss: 31.9320 - mean_absolute_error: 4.5759 - val_loss: 17.7207 - val_mean_absolute_error: 3.4351
# Epoch 22/25
# 86s - loss: 24.1074 - mean_absolute_error: 3.9949 - val_loss: 16.2626 - val_mean_absolute_error: 3.3169
# Epoch 23/25
# 86s - loss: 19.3602 - mean_absolute_error: 3.5635 - val_loss: 15.0335 - val_mean_absolute_error: 3.0899
# Epoch 24/25
# 86s - loss: 18.3058 - mean_absolute_error: 3.4563 - val_loss: 19.6148 - val_mean_absolute_error: 3.5311
# Epoch 25/25
# 86s - loss: 25.0420 - mean_absolute_error: 4.0877 - val_loss: 19.9069 - val_mean_absolute_error: 3.6198

# %% [markdown]
# #### Comparaison de plusieurs modèles
# Permettant de comparer la variation des hyper-paramètres du réseau.

# %%
def create_multiple_models(input_shape, nb_filters=16, nb_conv=5):
    
    models = []

    for j in [3, 5, 7]:
        model = Sequential()
        model.add(Conv2D(nb_filters, kernel_size=(j, j), strides=(1, 1),
                         activation='relu', padding='valid',
                         input_shape=input_shape))
        model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
        
        model.add(Conv2D(nb_filters*2, kernel_size=(j, j), activation='relu', padding='valid'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Flatten())
        model.add(Dropout(0.4))
        model.add(Dense(nb_filters*2, activation='relu'))
        model.add(Dense(1, activation='linear'))

        adam = Adam(lr=0.0001)
        model.compile(loss='mean_squared_error', optimizer=adam, metrics=['mae'])
        models.append(model)
    
    return models

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
models = create_multiple_models(input_shape, nb_filters=32, nb_conv=5)

# %% [markdown]
# ##### Entrainement de plusieurs modèles

# %%
def train_multiple_models(x_train, y_train, batch_size, nb_epoch, models_to_train):
    histories = list()
    models = list()
    for model in models_to_train:
        history, model = train_model(model, x_train, y_train, batch_size=batch_size, nb_epoch=nb_epoch)
        histories.append(history)
        models.append(model)
        print("\n")
    return histories, models

# %%
histories, models = train_multiple_models(x_train, y_train, batch_size=BATCH_SIZE, nb_epoch=NB_EPOCH, 
                                          models_to_train=models)
# Out:
# Train on 215 samples, validate on 54 samples
# Epoch 1/25
# 26s - loss: 83420.3190 - mean_absolute_error: 113.3937 - val_loss: 1354.8335 - val_mean_absolute_error: 30.5929
# Epoch 2/25
# 25s - loss: 994.1364 - mean_absolute_error: 25.2003 - val_loss: 1354.8314 - val_mean_absolute_error: 30.5929
# Epoch 3/25
# 25s - loss: 994.1311 - mean_absolute_error: 25.2002 - val_loss: 1354.8211 - val_mean_absolute_error: 30.5927
# Epoch 4/25
# 25s - loss: 994.1210 - mean_absolute_error: 25.2000 - val_loss: 1354.8069 - val_mean_absolute_error: 30.5925
# Epoch 5/25
# 25s - loss: 994.1085 - mean_absolute_error: 25.1998 - val_loss: 1354.7908 - val_mean_absolute_error: 30.5922
# Epoch 6/25
# 25s - loss: 994.0947 - mean_absolute_error: 25.1995 - val_loss: 1354.7728 - val_mean_absolute_error: 30.5919
# Epoch 7/25
# 25s - loss: 994.0791 - mean_absolute_error: 25.1992 - val_loss: 1354.7529 - val_mean_absolute_error: 30.5916
# Epoch 8/25
# 25s - loss: 994.0623 - mean_absolute_error: 25.1988 - val_loss: 1354.7317 - val_mean_absolute_error: 30.5912
# Epoch 9/25
# 25s - loss: 994.0443 - mean_absolute_error: 25.1985 - val_loss: 1354.7095 - val_mean_absolute_error: 30.5909
# Epoch 10/25
# 25s - loss: 994.0253 - mean_absolute_error: 25.1981 - val_loss: 1354.6862 - val_mean_absolute_error: 30.5905
# Epoch 11/25
# 25s - loss: 994.0057 - mean_absolute_error: 25.1977 - val_loss: 1354.6610 - val_mean_absolute_error: 30.5901
# Epoch 12/25
# 25s - loss: 993.9853 - mean_absolute_error: 25.1973 - val_loss: 1354.6346 - val_mean_absolute_error: 30.5896
# Epoch 13/25
# 25s - loss: 993.9628 - mean_absolute_error: 25.1969 - val_loss: 1354.6083 - val_mean_absolute_error: 30.5892
# Epoch 14/25
# 25s - loss: 993.9406 - mean_absolute_error: 25.1965 - val_loss: 1354.5803 - val_mean_absolute_error: 30.5888
# Epoch 15/25
# 25s - loss: 993.9169 - mean_absolute_error: 25.1960 - val_loss: 1354.5516 - val_mean_absolute_error: 30.5883
# Epoch 16/25
# 25s - loss: 993.8931 - mean_absolute_error: 25.1955 - val_loss: 1354.5208 - val_mean_absolute_error: 30.5878
# Epoch 17/25
# 25s - loss: 993.8678 - mean_absolute_error: 25.1950 - val_loss: 1354.4904 - val_mean_absolute_error: 30.5873
# Epoch 18/25
# 25s - loss: 993.8421 - mean_absolute_error: 25.1945 - val_loss: 1354.4588 - val_mean_absolute_error: 30.5868
# Epoch 19/25
# 25s - loss: 993.8158 - mean_absolute_error: 25.1940 - val_loss: 1354.4255 - val_mean_absolute_error: 30.5862
# Epoch 20/25
# 26s - loss: 993.7885 - mean_absolute_error: 25.1935 - val_loss: 1354.3922 - val_mean_absolute_error: 30.5857
# Epoch 21/25
# 27s - loss: 993.7619 - mean_absolute_error: 25.1929 - val_loss: 1354.3576 - val_mean_absolute_error: 30.5851
# Epoch 22/25
# 26s - loss: 993.7322 - mean_absolute_error: 25.1924 - val_loss: 1354.3249 - val_mean_absolute_error: 30.5846
# Epoch 23/25
# 25s - loss: 993.7041 - mean_absolute_error: 25.1918 - val_loss: 1354.2888 - val_mean_absolute_error: 30.5840
# Epoch 24/25
# 25s - loss: 993.6742 - mean_absolute_error: 25.1912 - val_loss: 1354.2519 - val_mean_absolute_error: 30.5834
# Epoch 25/25
# 25s - loss: 993.6439 - mean_absolute_error: 25.1906 - val_loss: 1354.2150 - val_mean_absolute_error: 30.5828
#
#
# Train on 215 samples, validate on 54 samples
# Epoch 1/25
# 43s - loss: 78369.1181 - mean_absolute_error: 151.5832 - val_loss: 3030.5164 - val_mean_absolute_error: 51.0153
# Epoch 2/25
# 42s - loss: 1197.6941 - mean_absolute_error: 28.2828 - val_loss: 1278.1216 - val_mean_absolute_error: 29.7777
# Epoch 3/25
# 42s - loss: 739.1135 - mean_absolute_error: 20.8417 - val_loss: 396.6635 - val_mean_absolute_error: 18.1294
# Epoch 4/25
# 42s - loss: 353.1151 - mean_absolute_error: 16.8845 - val_loss: 352.8475 - val_mean_absolute_error: 17.2066
# Epoch 5/25
# 43s - loss: 284.2856 - mean_absolute_error: 14.5846 - val_loss: 359.6932 - val_mean_absolute_error: 16.9563
# Epoch 6/25
# 43s - loss: 237.2467 - mean_absolute_error: 13.5079 - val_loss: 280.5500 - val_mean_absolute_error: 15.0993
# Epoch 7/25
# 42s - loss: 166.0857 - mean_absolute_error: 11.1130 - val_loss: 192.3339 - val_mean_absolute_error: 11.9118
# Epoch 8/25
# 43s - loss: 92.3843 - mean_absolute_error: 7.6613 - val_loss: 116.3677 - val_mean_absolute_error: 8.0458
# Epoch 9/25
# 42s - loss: 49.1355 - mean_absolute_error: 5.2693 - val_loss: 111.8173 - val_mean_absolute_error: 6.9207
# Epoch 10/25
# 42s - loss: 43.5668 - mean_absolute_error: 4.7416 - val_loss: 89.7892 - val_mean_absolute_error: 6.0823
# Epoch 11/25
# 43s - loss: 36.8391 - mean_absolute_error: 4.5479 - val_loss: 67.7358 - val_mean_absolute_error: 5.2863
# Epoch 12/25
# 42s - loss: 26.8104 - mean_absolute_error: 3.7290 - val_loss: 62.7008 - val_mean_absolute_error: 4.8108
# Epoch 13/25
# 42s - loss: 21.7733 - mean_absolute_error: 3.3434 - val_loss: 54.4449 - val_mean_absolute_error: 4.8252
# Epoch 14/25
# 43s - loss: 19.4646 - mean_absolute_error: 3.2750 - val_loss: 54.0467 - val_mean_absolute_error: 4.5450
# Epoch 15/25
# 42s - loss: 16.1162 - mean_absolute_error: 2.8699 - val_loss: 50.9663 - val_mean_absolute_error: 4.3433
# Epoch 16/25
# 42s - loss: 15.6659 - mean_absolute_error: 2.9117 - val_loss: 51.1161 - val_mean_absolute_error: 4.3631
# Epoch 17/25
# 42s - loss: 12.3178 - mean_absolute_error: 2.5750 - val_loss: 45.3230 - val_mean_absolute_error: 4.1435
# Epoch 18/25
# 43s - loss: 13.1924 - mean_absolute_error: 2.8069 - val_loss: 46.2994 - val_mean_absolute_error: 4.1156
# Epoch 19/25
# 43s - loss: 12.8583 - mean_absolute_error: 2.7362 - val_loss: 45.8686 - val_mean_absolute_error: 4.1357
# Epoch 20/25
# 42s - loss: 12.2501 - mean_absolute_error: 2.7285 - val_loss: 41.2001 - val_mean_absolute_error: 4.0748
# Epoch 21/25
# 42s - loss: 9.1817 - mean_absolute_error: 2.3558 - val_loss: 40.1022 - val_mean_absolute_error: 4.1022
# Epoch 22/25
# 44s - loss: 7.9768 - mean_absolute_error: 2.2054 - val_loss: 43.2163 - val_mean_absolute_error: 4.0311
# Epoch 23/25
# 43s - loss: 6.9060 - mean_absolute_error: 2.0535 - val_loss: 42.0731 - val_mean_absolute_error: 3.8551
# Epoch 24/25
# 42s - loss: 7.1996 - mean_absolute_error: 2.1060 - val_loss: 45.0964 - val_mean_absolute_error: 4.1780
# Epoch 25/25
# 43s - loss: 7.9781 - mean_absolute_error: 2.3149 - val_loss: 46.1675 - val_mean_absolute_error: 4.2396
#
#
# Train on 215 samples, validate on 54 samples
# Epoch 1/25
# 65s - loss: 209507.1450 - mean_absolute_error: 260.3765 - val_loss: 929.7742 - val_mean_absolute_error: 23.3204
# Epoch 2/25
# 64s - loss: 1530.7671 - mean_absolute_error: 33.7376 - val_loss: 441.9676 - val_mean_absolute_error: 19.2269
# Epoch 3/25
# 64s - loss: 372.7023 - mean_absolute_error: 16.6953 - val_loss: 489.7640 - val_mean_absolute_error: 19.5923
# Epoch 4/25
# 64s - loss: 376.0174 - mean_absolute_error: 16.7024 - val_loss: 464.6901 - val_mean_absolute_error: 19.1883
# Epoch 5/25
# 64s - loss: 343.9105 - mean_absolute_error: 16.3673 - val_loss: 435.6124 - val_mean_absolute_error: 18.5732
# Epoch 6/25
# 65s - loss: 285.4891 - mean_absolute_error: 14.7404 - val_loss: 257.9507 - val_mean_absolute_error: 14.2672
# Epoch 7/25
# 64s - loss: 124.7971 - mean_absolute_error: 8.9331 - val_loss: 114.4261 - val_mean_absolute_error: 7.8883
# Epoch 8/25
# 64s - loss: 70.7852 - mean_absolute_error: 6.3241 - val_loss: 91.7863 - val_mean_absolute_error: 6.4330
# Epoch 9/25
# 64s - loss: 54.1650 - mean_absolute_error: 5.4237 - val_loss: 101.7902 - val_mean_absolute_error: 6.6095
# Epoch 10/25
# 64s - loss: 45.5348 - mean_absolute_error: 4.8487 - val_loss: 62.3529 - val_mean_absolute_error: 4.9213
# Epoch 11/25
# 64s - loss: 40.1448 - mean_absolute_error: 4.7394 - val_loss: 66.1767 - val_mean_absolute_error: 4.9227
# Epoch 12/25
# 64s - loss: 34.3383 - mean_absolute_error: 4.4414 - val_loss: 55.8245 - val_mean_absolute_error: 4.6125
# Epoch 13/25
# 65s - loss: 31.8547 - mean_absolute_error: 4.3067 - val_loss: 48.6355 - val_mean_absolute_error: 4.6668
# Epoch 14/25
# 66s - loss: 25.2970 - mean_absolute_error: 3.9612 - val_loss: 58.9984 - val_mean_absolute_error: 4.9731
# Epoch 15/25
# 67s - loss: 22.5978 - mean_absolute_error: 3.6485 - val_loss: 43.1090 - val_mean_absolute_error: 4.0017
# Epoch 16/25
# 64s - loss: 24.2716 - mean_absolute_error: 3.7174 - val_loss: 51.8728 - val_mean_absolute_error: 4.5040
# Epoch 17/25
# 64s - loss: 20.9904 - mean_absolute_error: 3.6699 - val_loss: 50.5651 - val_mean_absolute_error: 4.3426
# Epoch 18/25
# 66s - loss: 21.6643 - mean_absolute_error: 3.7103 - val_loss: 42.5369 - val_mean_absolute_error: 3.9985
# Epoch 19/25
# 65s - loss: 16.6438 - mean_absolute_error: 3.1259 - val_loss: 36.9244 - val_mean_absolute_error: 3.7666
# Epoch 20/25
# 64s - loss: 18.4735 - mean_absolute_error: 3.2977 - val_loss: 46.9622 - val_mean_absolute_error: 4.2173
# Epoch 21/25
# 64s - loss: 18.3987 - mean_absolute_error: 3.2762 - val_loss: 36.7446 - val_mean_absolute_error: 3.7318
# Epoch 22/25
# 64s - loss: 16.7907 - mean_absolute_error: 3.1147 - val_loss: 35.8691 - val_mean_absolute_error: 3.8059
# Epoch 23/25
# 64s - loss: 20.2677 - mean_absolute_error: 3.4763 - val_loss: 41.9982 - val_mean_absolute_error: 4.1732
# Epoch 24/25
# 64s - loss: 18.2410 - mean_absolute_error: 3.4550 - val_loss: 52.2415 - val_mean_absolute_error: 4.7792
# Epoch 25/25
# 64s - loss: 13.3587 - mean_absolute_error: 2.7955 - val_loss: 36.0367 - val_mean_absolute_error: 3.8321

# %% [markdown]
# #### Affichage des courbes d'entrainement

# %%
def plot_curves_train(history, offset=0, title_name=""):
    # summarize history for accuracy
    plt.figure(figsize=(15, 6))
    plt.plot(list(range(offset, len(history.history['mean_absolute_error']))), 
             history.history['mean_absolute_error'][offset:])
    plt.plot(list(range(offset, len(history.history['val_mean_absolute_error']))), 
             history.history['val_mean_absolute_error'][offset:])
    plt.title('model error for {}'.format(title_name))
    plt.ylabel('MAE')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.figure(figsize=(15, 6))
    plt.plot(list(range(offset, len(history.history['loss']))), 
             history.history['loss'][offset:])
    plt.plot(list(range(offset, len(history.history['val_loss']))), 
             history.history['val_loss'][offset:])
    plt.title('model loss for {}'.format(title_name))
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
def plot_multiples_curves(histories, offset=0):
    plt.figure(figsize=(15, 6))
    for i in range(len(histories)):
        plt.plot(list(range(offset, len(histories[i].history['val_mean_absolute_error']))), 
                 histories[i].history['val_mean_absolute_error'][offset:])
    plt.title('model error')
    plt.ylabel('MAE')
    plt.xlabel('epoch')
    plt.legend(['3', '5', '7'], loc='upper right')
    plt.show()

# %%
plot_multiples_curves(histories[0:], offset=1)

# %%
plot_curves_train(history, offset=0, title_name="")

# %% [markdown]
# ##### Prédictions sur les données de test et évaluation

# %%
prediction = model.predict(x_test)
prediction = prediction.reshape(1, -1)[0]
print(prediction)
print(y_test)

MSE = mean_squared_error(y_test, prediction)
R2 = r2_score(y_test, prediction)

print("\nMSE : {}".format(round(MSE, 3)))
print("R2 : {}".format(round(R2, 3)))
# Out:
# [6.31403160e+01 1.14271679e+01 4.44346924e+01 4.04170418e+01
#  1.37520866e+01 1.35373411e+01 3.21545372e+01 4.09108162e+01
#  5.35767212e+01 1.66166134e+01 3.40971112e+00 9.18514824e+00
#  8.85954571e+00 1.51491871e+01 9.52187920e+00 9.23998165e+00
#  3.66178932e+01 3.75143547e+01 3.39383163e+01 2.25752811e+01
#  4.69438286e+01 5.37068292e-04 8.05735874e+00 1.43002319e+01
#  3.75170212e+01 6.01988373e+01 3.81805092e-01 5.63061829e+01
#  3.16959238e+00 8.76997375e+00 9.64181042e+00 4.94754677e+01
#  3.83465271e+01 1.04622698e+01 2.48419437e+01 1.20229702e+01
#  5.99824944e+01 3.69212341e+01 2.43720531e+01 4.39152002e+00
#  6.08514938e+01 5.37068292e-04 2.57038879e+01 4.36985397e+01
#  1.32134581e+01 4.27054367e+01 1.29092283e+01 2.23443508e+00
#  4.68915701e+00 2.95794621e+01 1.11594563e+01 5.37068292e-04
#  3.63866005e+01 8.92504311e+00 2.12663975e+01 1.64094448e+01
#  6.23017216e+00 4.06989174e+01 1.66554141e+00 4.73786306e+00
#  4.41201630e+01 3.71120911e+01 2.06473637e+01 5.61588745e+01
#  1.47278290e+01 1.42106266e+01 3.98224068e+01 4.61656075e+01
#  4.21393929e+01 9.32619381e+00 4.55989380e+01 2.89270020e+01
#  5.20212708e+01 5.23312645e+01 2.40342464e+01 9.67451286e+00
#  4.26968575e+01 5.50920906e+01 1.14943180e+01 5.37068292e-04
#  1.50727329e+01 5.37068292e-04 5.37068292e-04 5.43112488e+01
#  5.37068292e-04 5.37068292e-04 7.06531754e+01 4.74469032e+01
#  9.39948940e+00 1.35595131e+01 3.99605064e+01 5.37068292e-04
#  5.08753624e+01 4.81998940e+01 1.22843809e-01 1.57894888e+01
#  4.05745163e+01 1.24036684e+01 2.31480999e+01 1.49439001e+01
#  2.74527550e+01 4.75106430e+01 1.17239971e+01 2.13230610e+00
#  3.67478561e+01 2.48190975e+01 1.24643879e+01 1.14371157e+01
#  5.66342392e+01 8.45024884e-02 4.34212265e+01 3.51585274e+01
#  4.96919823e+01 2.05649281e+00 4.81451492e+01 3.79174042e+01
#  1.42346725e+01 6.49437180e+01 1.03549786e+01 1.31830530e+01
#  9.79490757e+00 1.35432739e+01 1.20845804e+01 3.77019386e+01
#  4.24190254e+01 1.16297655e+01 1.68899479e+01 1.27324276e+01
#  6.10630455e+01 7.17292786e+00 1.11051579e+01 1.17779045e+01
#  5.23508759e+01 5.16546974e+01 5.37068292e-04]
# [61. 12. 39. 39. 16. 14. 37. 45. 61. 15.  3. 13. 12.  9. 13.  9. 40. 39.
#  38. 27. 42.  6.  9. 17. 41. 64.  6. 59. 12.  8. 12. 59. 42. 12. 26. 16.
#  54. 41. 26.  7. 61.  2. 28. 46. 13. 42. 16.  6.  8. 40. 11.  7. 37. 14.
#  25. 23. 11. 39.  4.  5. 42. 36. 18. 61. 20. 14. 40. 42. 42. 10. 53. 28.
#  62. 60. 27. 12. 50. 50. 14.  5. 14.  7.  8. 60.  5.  3. 63. 56. 12. 14.
#  40.  3. 56. 57.  5.  6. 41. 13. 26. 16. 28. 44. 13.  5. 39. 28. 16. 14.
#  59.  8. 41. 36. 38.  8. 44. 37. 16. 58. 12. 15. 12. 12. 16. 39. 40. 13.
#  24. 13. 57. 11. 13. 14. 59. 62.  7.]
#
# MSE : 19.799999237060547
# R2 : 0.944
